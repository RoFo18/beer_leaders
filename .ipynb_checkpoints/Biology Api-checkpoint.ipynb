# %%
#set depdendies
import pandas as pd
import json
import requests
import numpy as np
import matplotlib.pyplot as plt
from pprint import pprint
import seaborn as sns; sns.set(color_codes=True)
from scipy import stats

# %%
url = "https://api.datausa.io/api/?sort=desc&show=geo&required=grads_total&sumlevel=state&cip=26&year=all"

# %%
# Make an API call to the API and convert response object to JSON
json = requests.get(url).json()

# %%
#see the data
#json

# %%
# Converting the response to JSON
data = [dict(zip(json["headers"], d)) for d in json["data"]]

# %%
x =data[0]

# %%
# explore the structure of the returned JSON object
json['headers']
# Out:
# ['year', 'geo', 'cip', 'grads_total']

# %%
r = requests.get(url)
x = r.json()
biology_df = pd.DataFrame(data)

biology_df.head()
# Out:
#   cip        geo  grads_total  year
# 0  26  04000US01         1786  2013
# 1  26  04000US02          138  2013
# 2  26  04000US04         2316  2013
# 3  26  04000US05          754  2013
# 4  26  04000US06        16046  2013

# %%
biology_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162 entries, 0 to 161
# Data columns (total 4 columns):
# cip            162 non-null object
# geo            162 non-null object
# grads_total    162 non-null int64
# year           162 non-null int64
# dtypes: int64(2), object(2)
# memory usage: 5.1+ KB

# %%
biology_df['geo'][0][-2:]
# Out:
# '01'

# %%
# make a new column that takes just the last two digits
biology_df['State'] = biology_df['geo'].str[-2:]
biology_df.head()
# Out:
#   cip        geo  grads_total  year State
# 0  26  04000US01         1786  2013    01
# 1  26  04000US02          138  2013    02
# 2  26  04000US04         2316  2013    04
# 3  26  04000US05          754  2013    05
# 4  26  04000US06        16046  2013    06

# %%
biology_df.dtypes
# Out:
# cip            object
# geo            object
# grads_total     int64
# year            int64
# State          object
# dtype: object

# %%
code_df = pd.read_csv("/Users/RoFo/Dropbox/Data_Science_BC/codes.csv")
#code_df = code_df.drop('Unnamed: 2', 1)
#changed it into an object
code_df['Code'] = code_df['Code'].apply('{:0>2}'.format)
code_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 2 columns):
# Code     54 non-null object
# State    54 non-null object
# dtypes: object(2)
# memory usage: 944.0+ bytes

# %%
code_df.dtypes
# Out:
# Code     object
# State    object
# dtype: object

# %%
# grad_merge = final graduate data set
merged_df = biology_df.merge(code_df, left_on='State', right_on='Code', how='outer')
grad_merge_df = merged_df.drop(['cip','geo','State_x','Code'], axis=1)
grad_merge_df
# Out:
#      grads_total  year               State_y
# 0           1786  2013               Alabama
# 1           1834  2014               Alabama
# 2           1847  2015               Alabama
# 3            138  2013                Alaska
# 4            134  2014                Alaska
# 5            149  2015                Alaska
# 6           2316  2013               Arizona
# 7           2375  2014               Arizona
# 8           2572  2015               Arizona
# 9            754  2013              Arkansas
# 10           892  2014              Arkansas
# 11           882  2015              Arkansas
# 12         16046  2013            California
# 13         16649  2014            California
# 14         16972  2015            California
# 15          2477  2013              Colorado
# 16          2761  2014              Colorado
# 17          2853  2015              Colorado
# 18          1794  2013           Connecticut
# 19          1866  2014           Connecticut
# 20          1952  2015           Connecticut
# 21           319  2013              Delaware
# 22           335  2014              Delaware
# 23           347  2015              Delaware
# 24           967  2013  District of Columbia
# 25          1001  2014  District of Columbia
# 26          1059  2015  District of Columbia
# 27          6718  2013               Florida
# 28          7025  2014               Florida
# 29          7688  2015               Florida
# ..           ...   ...                   ...
# 132         1477  2013                  Utah
# 133         1537  2014                  Utah
# 134         1588  2015                  Utah
# 135          437  2013               Vermont
# 136          444  2014               Vermont
# 137          478  2015               Vermont
# 138         3549  2013              Virginia
# 139         3723  2014              Virginia
# 140         3947  2015              Virginia
# 141         2648  2013            Washington
# 142         2832  2014            Washington
# 143         3085  2015            Washington
# 144          625  2013         West Virginia
# 145          616  2014         West Virginia
# 146          596  2015         West Virginia
# 147         3134  2013             Wisconsin
# 148         3262  2014             Wisconsin
# 149         3336  2015             Wisconsin
# 150          209  2013               Wyoming
# 151          256  2014               Wyoming
# 152          249  2015               Wyoming
# 153           10  2013                  Guam
# 154           14  2014                  Guam
# 155           23  2015                  Guam
# 156         1572  2013           Puerto Rico
# 157         1926  2014           Puerto Rico
# 158         1972  2015           Puerto Rico
# 159           20  2013     US Virgin Islands
# 160           26  2014     US Virgin Islands
# 161           23  2015     US Virgin Islands
#
# [162 rows x 3 columns]

# %%
#now merge brewery data sets (Brewery and Convert)
Brewery_df = pd.read_csv("/Users/RoFo/Dropbox/Data_Science_BC/Brewery.csv")
Brewery_df = Brewery_df.rename(columns={'Unnamed: 0': 'State'})
Brewery_df.head()
# Out:
#   State  2013  2014  2015
# 0    AK    25    28    35
# 1    AL    23    25    30
# 2    AR    18    23    29
# 3    AZ    59    77    91
# 4    CA   528   654   788

# %%
Convert_df = pd.read_csv("/Users/RoFo/Dropbox/Data_Science_BC/Convert.csv")
Convert_df = Convert_df.rename(columns={'Abbreviation': 'State Ab', 'FullStateName' : 'Full State Name'})
Convert_df.head()
# Out:
#   State Ab Full State Name
# 0       AL         Alabama
# 1       AK          Alaska
# 2       AZ         Arizona
# 3       AR        Arkansas
# 4       CA      California

# %%
#final_beer_merge = final brewery data set
the_merged_brew_df = Brewery_df.merge(Convert_df, left_on='State', right_on='State Ab', how='outer')
final_beer_merge_df = the_merged_brew_df.drop(['State Ab'], axis=1)
final_beer_merge_df.head()
# Out:
#   State   2013   2014   2015 Full State Name
# 0    AK   25.0   28.0   35.0          Alaska
# 1    AL   23.0   25.0   30.0         Alabama
# 2    AR   18.0   23.0   29.0        Arkansas
# 3    AZ   59.0   77.0   91.0         Arizona
# 4    CA  528.0  654.0  788.0      California

# %%
final_beer_merge_df.dtypes
# Out:
# State               object
# 2013               float64
# 2014               float64
# 2015               float64
# Full State Name     object
# dtype: object

# %%
grad_merge_df.dtypes
# Out:
# grads_total     int64
# year            int64
# State_y        object
# dtype: object

# %%
print(type(final_beer_merge_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
final_beer_merge_df.columns
# Out:
# Index(['State', '2013', '2014', '2015', 'Full State Name'], dtype='object')

# %%
grad_merge_df.columns
# Out:
# Index(['grads_total', 'year', 'State_y'], dtype='object')

# %%
print(type(grad_merge_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#get big data set --> merge final_beer_merge and grad_merge data sets
bio_beer_df= final_beer_merge_df.merge(grad_merge_df, left_on='Full State Name', right_on='State_y', how='outer')

# %%
bio_beer_df.head()
# Out:
#   State Full State Name    year  2013 Brew  2014 Brew  2015 Brew  grads_total  \
# 0    AK          Alaska  2013.0       25.0       28.0       35.0        138.0
# 1    AK          Alaska  2014.0       25.0       28.0       35.0        134.0
# 2    AK          Alaska  2015.0       25.0       28.0       35.0        149.0
# 3    AL         Alabama  2013.0       23.0       25.0       30.0       1786.0
# 4    AL         Alabama  2014.0       23.0       25.0       30.0       1834.0
#
#    2013_grads  2014_grads  2015_grads
# 0       138.0       134.0       149.0
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3      1786.0      1834.0      1847.0
# 4         NaN         NaN         NaN

# %%
bio_beer_df = bio_beer_df[['State', 'Full State Name', 'year', '2013', '2014', '2015', 'grads_total']]
bio_beer_df = bio_beer_df.rename(columns={'2013': '2013 Brew', '2014' : '2014 Brew', '2015' : '2015 Brew'})

# %%
#itterows
grads_2013 = []

summary_beers = bio_beer_df

for index, row in summary_beers.iterrows():
    if row["year"] == 2013.0:
        placeholder = row["grads_total"]
        summary_beers.loc[index,"2013_grads"] = placeholder
    elif row["year"] == 2014.0:
        placeholder = row["grads_total"]
        summary_beers.loc[index-1,"2014_grads"] = placeholder
    elif row["year"] == 2015.0:
        placeholder = row["grads_total"]
        summary_beers.loc[index-2,"2015_grads"] = placeholder

summary_beers = summary_beers.dropna(axis=0, how="any")
summary_beers = summary_beers.set_index("State")
summary_beers.head()
# Out:
#       Full State Name    year  2013 Brew  2014 Brew  2015 Brew  grads_total  \
# State
# AK             Alaska  2013.0       25.0       28.0       35.0        138.0
# AL            Alabama  2013.0       23.0       25.0       30.0       1786.0
# AR           Arkansas  2013.0       18.0       23.0       29.0        754.0
# AZ            Arizona  2013.0       59.0       77.0       91.0       2316.0
# CA         California  2013.0      528.0      654.0      788.0      16046.0
#
#        2013_grads  2014_grads  2015_grads
# State
# AK          138.0       134.0       149.0
# AL         1786.0      1834.0      1847.0
# AR          754.0       892.0       882.0
# AZ         2316.0      2375.0      2572.0
# CA        16046.0     16649.0     16972.0

# %%
pop_df = pd.read_csv("/Users/RoFo/Dropbox/Data_Science_BC/pop.csv")
pop_beer = summary_beers.merge(pop_df, left_on='Full State Name', right_on='Unnamed: 0', how='outer')
pop_beer = pop_beer.drop('Unnamed: 0', 1)
pop_beer = pop_beer.drop('year', 1)
pop_beer.head()
# Out:
#   Full State Name  2013 Brew  2014 Brew  2015 Brew  grads_total  2013_grads  \
# 0          Alaska       25.0       28.0       35.0        138.0       138.0
# 1         Alabama       23.0       25.0       30.0       1786.0      1786.0
# 2        Arkansas       18.0       23.0       29.0        754.0       754.0
# 3         Arizona       59.0       77.0       91.0       2316.0      2316.0
# 4      California      528.0      654.0      788.0      16046.0     16046.0
#
#    2014_grads  2015_grads  2013 Pop  2014 Pop  2015 Pop
# 0       134.0       149.0    737442    737046    738432
# 1      1834.0      1847.0   4830533   4846411   4858979
# 2       892.0       882.0   2957957   2966835   2978204
# 3      2375.0      2572.0   6630799   6728783   6828065
# 4     16649.0     16972.0  38414128  38792291  39144818

# %%
brew_2013 = (pop_beer["2013 Brew"]/pop_beer["2013 Pop"])*10000
brew_2014 = (pop_beer["2014 Brew"]/pop_beer["2014 Pop"])*10000
brew_2015 = (pop_beer["2015 Brew"]/pop_beer["2015 Pop"])*10000
grad_2013 = (pop_beer["2013_grads"]/pop_beer["2013 Pop"])*10000
grad_2014 = (pop_beer["2014_grads"]/pop_beer["2014 Pop"])*10000
grad_2015 = (pop_beer["2015_grads"]/pop_beer["2015 Pop"])*10000

beer_data = {"State Name": pop_beer['Full State Name'],"Brewery 2013" : brew_2013,
             "Brewery 2014" : brew_2014, "Brewery 2015" : brew_2015, 
             "Graduates 2013" : grad_2013, "Graduates 2014" : grad_2014, 
             "Graduates 2015" : grad_2015 }

big_beer = pd.DataFrame(beer_data)
#big_beer = big_beer.set_index("State Name")
big_beer.sort_values("Brewery 2015", ascending=False).reset_index()
# Out:
#     index  Brewery 2013  Brewery 2014  Brewery 2015  Graduates 2013  \
# 0      46      0.717556      0.813700      1.054242        6.968263
# 1      26      0.483043      0.605911      0.716395        3.972784
# 2      37      0.560077      0.614424      0.697448        3.757609
# 3       5      0.443927      0.560163      0.645093        4.699180
# 4      21      0.451543      0.533732      0.631898        4.665941
# 5      47      0.381456      0.444560      0.534144        3.797352
# 6       0      0.339010      0.379895      0.473977        1.871334
# 7      30      0.264618      0.346387      0.473468        4.211211
# 8      13      0.260419      0.311964      0.344425        4.575935
# 9      32      0.230007      0.287692      0.340510        2.731337
# 10     48      0.254194      0.291695      0.327480        5.456458
# 11     22      0.196960      0.258161      0.318466        4.575524
# 12     23      0.138363      0.207069      0.258671        5.187674
# 13     15      0.144585      0.175814      0.228108        3.556797
# 14     12      0.174632      0.192958      0.227280        4.970533
# 15      8      0.140487      0.160262      0.222003        3.447333
# 16     41      0.141966      0.175787      0.221324        4.400961
# 17     38      0.143153      0.182120      0.217145        5.142552
# 18     27      0.126962      0.155930      0.206118        3.988652
# 19     29      0.133740      0.185876      0.205676        4.680897
# 20      4      0.137449      0.168590      0.201304        4.177109
# 21      7      0.169351      0.181863      0.193387       14.887459
# 22     45      0.102808      0.140488      0.184898        4.292518
# 23     19      0.122227      0.145075      0.182503        7.493132
# 24     11      0.120673      0.140820      0.181615        2.988433
# 25     34      0.098014      0.129121      0.166197        4.727025
# 26      6      0.108419      0.139091      0.164305        4.987257
# 27     14      0.095426      0.127308      0.163297        3.776694
# 28     35      0.098512      0.130206      0.161021        3.768504
# 29     24      0.104241      0.126983      0.147937        3.952871
# 30     28      0.110554      0.135128      0.145324        4.961126
# 31     39      0.113976      0.132713      0.142005        6.373141
# 32     33      0.093178      0.119791      0.134909        1.945981
# 33     42      0.078508      0.105379      0.133327        2.827837
# 34      3      0.088979      0.114434      0.133273        3.492792
# 35     16      0.086367      0.093023      0.127076        3.409762
# 36     20      0.072439      0.092045      0.121537        5.394169
# 37     17      0.056838      0.086117      0.108472        2.882801
# 38     40      0.062913      0.076618      0.104164        4.741535
# 39      9      0.057669      0.079375      0.101128        3.428519
# 40      2      0.060853      0.077524      0.097374        2.549057
# 41     44      0.082654      0.091696      0.096798        5.086640
# 42     49      0.048570      0.070318      0.092184        3.372936
# 43     43      0.048301      0.063012      0.080090        3.531231
# 44     31      0.041539      0.054817      0.079259        3.625082
# 45      1      0.047614      0.051585      0.061741        3.697315
# 46     36      0.044117      0.046396      0.053690        3.230909
# 47     18      0.032415      0.036567      0.053525        3.924373
# 48     10      0.037031      0.047538      0.052864        3.522973
# 49     25      0.023404      0.033406      0.046786        4.443366
# 50     50           NaN           NaN           NaN             NaN
#
#     Graduates 2014  Graduates 2015            State Name
# 0         7.083972        7.635270               Vermont
# 1         4.417289        4.172520               Montana
# 2         4.064261        4.008462                Oregon
# 3         5.155363        5.228556              Colorado
# 4         5.051659        4.912256                 Maine
# 5         4.009533        4.302439            Washington
# 6         1.818068        2.017789                Alaska
# 7         4.631038        5.102930         New Hampshire
# 8         4.905781        5.178467                 Idaho
# 9         2.900890        2.834384            New Mexico
# 10        5.663753        5.780290             Wisconsin
# 11        4.712440        4.759853              Michigan
# 12        5.402112        5.729021             Minnesota
# 13        3.602672        3.808341               Indiana
# 14        5.142337        5.566761                  Iowa
# 15        3.579182        3.668332              Delaware
# 16        4.382963        4.799241          South Dakota
# 17        5.378400        5.567661          Pennsylvania
# 18        4.295607        4.457919        North Carolina
# 19        5.130166        5.189353              Nebraska
# 20        4.291832        4.335695            California
# 21       15.170436       15.753584  District of Columbia
# 22        4.470408        4.708342              Virginia
# 23        8.252994        8.523168         Massachusetts
# 24        3.105072        3.373840                Hawaii
# 25        4.731413        5.067239              New York
# 26        5.190886        5.435984           Connecticut
# 27        3.735390        3.709955              Illinois
# 28        4.133828        4.153814                  Ohio
# 29        4.126107        4.194835              Missouri
# 30        4.972704        5.086356          North Dakota
# 31        6.616697        7.299077          Rhode Island
# 32        2.194991        2.321121                Nevada
# 33        3.011708        3.199855             Tennessee
# 34        3.529613        3.766807               Arizona
# 35        3.407399        3.448227                Kansas
# 36        5.375421        5.625665              Maryland
# 37        2.850916        2.915194              Kentucky
# 38        4.841422        5.332766        South Carolina
# 39        3.529163        3.792559               Florida
# 40        3.006571        2.961516              Arkansas
# 41        5.219905        5.300544                  Utah
# 42        3.331979        3.231880         West Virginia
# 43        3.481216        3.668848                 Texas
# 44        3.553032        3.811113            New Jersey
# 45        3.784244        3.801210               Alabama
# 46        3.423024        3.520534              Oklahoma
# 47        3.854601        4.185647             Louisiana
# 48        3.843666        3.906074               Georgia
# 49        4.710295        4.688649           Mississippi
# 50             NaN             NaN                   NaN

# %%
big_beer.plot.scatter('Graduates 2013', 'Brewery 2015', marker="o", color = 'coral')

# %%
sns.jointplot(x='Graduates 2013', y='Brewery 2015', data=big_beer,  kind = "hex")

# %%
g = sns.regplot(x="Graduates 2013", y="Brewery 2013", data=big_beer,
    scatter_kws={"color":"blue","alpha":0.3,"s":90},
    line_kws={"color":"coral","alpha":0.5,"lw":4},marker="^")

# %%
#scipy for r squared

#stats.pearsonr("2013_grads", "2015 Brew", data=summary_beers))
stats.pearsonr(big_beer['Graduates 2013'], big_beer['Brewery 2015'])
# Out:
# (nan, 1.0)
